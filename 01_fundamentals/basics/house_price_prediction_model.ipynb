# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("D:\\ml-learning-journey\\01_fundamentals\\basics\\Rent.xlsx")

print(df.head())

print(pd.isnull(df).sum())
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100
# area    0
# rent    0
# dtype: int64
